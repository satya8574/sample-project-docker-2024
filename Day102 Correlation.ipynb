# %% [markdown]
# <a href="https://colab.research.google.com/github/satya8574/sample-project-docker-2024/blob/master/Day102%20Correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1==1
# Out:
# True

# %%
model = pg.anova(dv='Sales', between=['Location', 'Flavour'], data=df, ss_type=2)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !wget --no-check-certificate https://drive.google.com/uc?id=1M6ICGsUhO-IIFl_HPYpk9vJO-GJEszmC -O weight-height.csv
# Out:
# --2024-07-04 02:06:35--  https://drive.google.com/uc?id=1M6ICGsUhO-IIFl_HPYpk9vJO-GJEszmC
# Resolving drive.google.com (drive.google.com)... 74.125.20.139, 74.125.20.138, 74.125.20.100, ...
# Connecting to drive.google.com (drive.google.com)|74.125.20.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1M6ICGsUhO-IIFl_HPYpk9vJO-GJEszmC [following]
# --2024-07-04 02:06:36--  https://drive.usercontent.google.com/download?id=1M6ICGsUhO-IIFl_HPYpk9vJO-GJEszmC
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.142.132, 2607:f8b0:400e:c08::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.142.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 428120 (418K) [application/octet-stream]
# Saving to: ‘weight-height.csv’
#
# weight-height.csv   100%[===================>] 418.09K  --.-KB/s    in 0.005s
#
# ...

# %%
df_hw = pd.read_csv("weight-height.csv")

df_hw.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
sns.scatterplot(x=df_hw["Height"], y=df_hw["Weight"])
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
df_hw[["Height","Weight"]].corr()
# Out:
#           Height    Weight
# Height  1.000000  0.924756
# Weight  0.924756  1.000000

# %%
## Peasron correlation coffecient is 0.924 -> HIghly positive correlation

# %%
df_hw[["Height","Weight"]].corr()
# Out:
#           Height    Weight
# Height  1.000000  0.924756
# Weight  0.924756  1.000000

# %%
from scipy.stats import pearsonr,spearmanr

# %%
pearsonr(df_hw["Height"], df_hw["Weight"])
# Out:
# PearsonRResult(statistic=0.9247562987409148, pvalue=0.0)

# %%
spearmanr(df_hw["Height"], df_hw["Weight"])
# Out:
# SignificanceResult(statistic=0.9257076644210767, pvalue=0.0)

# %%
## H0 -> There is no correlation
## HA -> there is correlation

# %%
x = [1, 2, 3, 4, 5]
y = [5, 4, 3, 2, 1]
spearmanr(x,y)
# Out:
# SignificanceResult(statistic=-0.9999999999999999, pvalue=1.4042654220543672e-24)

# %%
df_hw["Height"].rank()
# Out:
# 0       9779.0
# 1       7165.0
# 2       9824.0
# 3       9137.0
# 4       8042.0
#          ...
# 9995    4854.0
# 9996    5642.0
# 9997    2814.0
# 9998    7382.0
# 9999    1329.0
# Name: Height, Length: 10000, dtype: float64

# %%
x = [1, 2, 3, 4, 5, 6, 7]
y = [10, 9, 2.5, 6, 4, 3, 2]
pearsonr(x,y)
# Out:
# PearsonRResult(statistic=-0.8285038835884277, pvalue=0.021280260007523352)

# %%
## manual ranking nad implem,entation

df_h_rank=df_hw["Height"].rank()
df_w_rank=df_hw["Weight"].rank()
pearsonr(df_h_rank,df_w_rank)
# Out:
# PearsonRResult(statistic=0.9257076644210764, pvalue=0.0)

# %%
df_hw["Height"]
# Out:
# 0       73.847017
# 1       68.781904
# 2       74.110105
# 3       71.730978
# 4       69.881796
#           ...
# 9995    66.172652
# 9996    67.067155
# 9997    63.867992
# 9998    69.034243
# 9999    61.944246
# Name: Height, Length: 10000, dtype: float64

# %%
df_h_rank
# Out:
# 0       9779.0
# 1       7165.0
# 2       9824.0
# 3       9137.0
# 4       8042.0
#          ...
# 9995    4854.0
# 9996    5642.0
# 9997    2814.0
# 9998    7382.0
# 9999    1329.0
# Name: Height, Length: 10000, dtype: float64

# %%
spearmanr(df_hw["Height"],df_hw["Weight"])
# Out:
# SignificanceResult(statistic=0.9257076644210767, pvalue=0.0)

# %%
# Out:
# PearsonRResult(statistic=0.9257076644210764, pvalue=0.0)

# %%
x = [1, 2, 3, 4, 5]
y = [5, 4, 3, 2, 1]
x_rank=pd.Series(x).rank()
y_rank=pd.Series(y).rank()

# %%
x_rank
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# dtype: float64

# %%
y_rank
# Out:
# 0    5.0
# 1    4.0
# 2    3.0
# 3    2.0
# 4    1.0
# dtype: float64

# %%
# !wget --no-check-certificate https://drive.google.com/uc?id=1s2Qad59GSQPT733fbS5fnULPhilRGj25 -O concrete_data.csv
# Out:
# --2024-07-04 03:24:50--  https://drive.google.com/uc?id=1s2Qad59GSQPT733fbS5fnULPhilRGj25
# Resolving drive.google.com (drive.google.com)... 74.125.20.102, 74.125.20.100, 74.125.20.101, ...
# Connecting to drive.google.com (drive.google.com)|74.125.20.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1s2Qad59GSQPT733fbS5fnULPhilRGj25 [following]
# --2024-07-04 03:24:50--  https://drive.usercontent.google.com/download?id=1s2Qad59GSQPT733fbS5fnULPhilRGj25
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.142.132, 2607:f8b0:400e:c08::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.142.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59010 (58K) [application/octet-stream]
# Saving to: ‘concrete_data.csv’
#
# concrete_data.csv   100%[===================>]  57.63K  --.-KB/s    in 0.001s
#
# ...

# %%
import pandas as pd
df = pd.read_csv('concrete_data.csv')
df.head()
# Out:
#    cement  blast_furnace_slag  fly_ash  water  superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    coarse_aggregate  fine_aggregate   age  concrete_compressive_strength
# 0            1040.0            676.0   28                          79.99
# 1            1055.0            676.0   28                          61.89
# 2             932.0            594.0  270                          40.27
# 3             932.0            594.0  365                          41.05
# 4             978.4            825.5  360                          44.30

# %%
df.shape
# Out:
# (1030, 9)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(font_scale=1.0)
plt.figure(figsize=(10,8))


correlation_values = df.corr(method = 'pearson')





sns.heatmap(correlation_values, vmax = .6, linewidths=0.01, square=True, annot=True, cmap="RdBu", linecolor="black")
plt.title('Correlation between features');

# %%
correlation_values
# Out:
#                                  cement  blast_furnace_slag   fly_ash  \
# cement                         1.000000           -0.275216 -0.397467
# blast_furnace_slag            -0.275216            1.000000 -0.323580
# fly_ash                       -0.397467           -0.323580  1.000000
# water                         -0.081587            0.107252 -0.256984
# superplasticizer               0.092386            0.043270  0.377503
# coarse_aggregate              -0.109349           -0.283999 -0.009961
# fine_aggregate                -0.222718           -0.281603  0.079108
# age                            0.081946           -0.044246 -0.154371
# concrete_compressive_strength  0.497832            0.134829 -0.105755
#
#                                   water  superplasticizer  coarse_aggregate  \
# cement                        -0.081587          0.092386         -0.109349
# blast_furnace_slag             0.107252          0.043270         -0.283999
# ...

# %%
sns.set(font_scale=1.0)
plt.figure(figsize=(10,8))
correlation_values = df.corr(method = 'spearman')
sns.heatmap(correlation_values,annot=True,linewidths=0.01,cmap="RdBu",linecolor="black")
# Out:
# <Axes: >
